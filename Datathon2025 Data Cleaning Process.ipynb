# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns

# %%
# This is to read the visitation dataset into google colab

vd = pd.read_csv("2025 Allianz Datathon Dataset (Visits Data).csv")
vd
# Out:
#      Year  Week  Mt. Baw Baw  Mt. Stirling  Mt. Hotham  Falls Creek  \
# 0    2014     1          555            60        3483         2790
# 1    2014     2          804            42        1253         1425
# 2    2014     3          993            30        2992         2101
# 3    2014     4         2976           165        9680         9544
# 4    2014     5        11112           645       29628        26211
# ..    ...   ...          ...           ...         ...          ...
# 160  2024    11         5977          1416       24260        38541
# 161  2024    12         3597           701       19289        42101
# 162  2024    13         1500           213       14487        25252
# 163  2024    14            0             0        2700        17137
# 164  2024    15            0             0           0        12950
#
#      Mt. Buller  Selwyn  Thredbo  Perisher  Charlotte Pass
# 0          8296    1041     5535      7370             408
# 1          1987     383     2090      2751             151
# 2          2413     597     3216      4255             230
# 3         18831    2877    15497     20265            1134
# 4         49217    8588    46546     61339            3403
# ..          ...     ...      ...       ...             ...
# 160       43387    6859    37608     49136            2667
# 161       36668    5969    33208     43382            2392
# 162       15415    3351    18120     23908            1323
# 163           0    1177     6270      8244             454
# 164           0     745     4103      5336             294
#
# [165 rows x 11 columns]

# %%
vd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            165 non-null    int64
#  1   Week            165 non-null    int64
#  2   Mt. Baw Baw     165 non-null    int64
#  3   Mt. Stirling    165 non-null    int64
#  4   Mt. Hotham      165 non-null    int64
#  5   Falls Creek     165 non-null    int64
#  6   Mt. Buller      165 non-null    int64
#  7   Selwyn          165 non-null    int64
#  8   Thredbo         165 non-null    int64
#  9   Perisher        165 non-null    int64
#  10  Charlotte Pass  165 non-null    int64
# dtypes: int64(11)
# memory usage: 14.3 KB

# %% [markdown]
# In the table below, there are no missing values for the visits dataset. Thus, no need to edit this file.

# %%
visits_missing_values_count = vd.isnull().sum()
visits_missing_values_count
# Out:
# Year              0
# Week              0
# Mt. Baw Baw       0
# Mt. Stirling      0
# Mt. Hotham        0
# Falls Creek       0
# Mt. Buller        0
# Selwyn            0
# Thredbo           0
# Perisher          0
# Charlotte Pass    0
# dtype: int64

# %%
x = pd.read_csv("2025 Allianz Datathon Dataset (Climate Data).csv")
x.head()
# Out:
#    Bureau of Meteorology station number  Year  Month  Day  \
# 0                                 71075  2010      1    1
# 1                                 71075  2010      1    2
# 2                                 71075  2010      1    3
# 3                                 71075  2010      1    4
# 4                                 71075  2010      1    5
#
#    Maximum temperature (Degree C)  Minimum temperature (Degree C)  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#    Rainfall amount (millimetres)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN

# %% [markdown]
# Next, the climate data from meteorology stations will be read. Unfortunately, there seems to be an indication that there are missing values for maximum temperature, minimum temperature and rainfall.

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39813 entries, 0 to 39812
# Data columns (total 7 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Bureau of Meteorology station number  39813 non-null  int64
#  1   Year                                  39813 non-null  int64
#  2   Month                                 39813 non-null  int64
#  3   Day                                   39813 non-null  int64
#  4   Maximum temperature (Degree C)        38275 non-null  float64
#  5   Minimum temperature (Degree C)        38280 non-null  float64
#  6   Rainfall amount (millimetres)         37857 non-null  float64
# dtypes: float64(3), int64(4)
# memory usage: 2.1 MB

# %%
x_missing_values_count = x.isnull().sum()
x_missing_values_count
# Out:
# Bureau of Meteorology station number       0
# Year                                       0
# Month                                      0
# Day                                        0
# Maximum temperature (Degree C)          1538
# Minimum temperature (Degree C)          1533
# Rainfall amount (millimetres)           1956
# dtype: int64

# %% [markdown]
# From here, some data cleaning was done in excel first in order to:
#
# - Remove all years from 2010 to 2013
# - Remove all days except for the ski season (from 9th of June to 21st September)
#
# This was done via Excel's filter function.
#
# 2025 was accidentally kept in the csv file but will not impact the final csv file used to create graphs and models.

# %%
# This is to read the newly edited climate excel file  into google colab

cd = pd.read_csv("climatedata_edit_1.csv")
cd
# Out:
#       Bureau of Meteorology station number  Year  Month  Day  \
# 0                                    71075  2014      6    9
# 1                                    71075  2014      6   10
# 2                                    71075  2014      6   11
# 3                                    71075  2014      6   12
# 4                                    71075  2014      6   13
# ...                                    ...   ...    ...  ...
# 8427                                 72161  2025      7   24
# 8428                                 72161  2025      7   25
# 8429                                 72161  2025      7   26
# 8430                                 72161  2025      7   27
# 8431                                 72161  2025      7   28
#
#       Maximum temperature (Degree C)  Minimum temperature (Degree C)  \
# 0                                3.4                            -1.8
# 1                                8.1                            -5.0
# 2                               13.4                            -5.1
# 3                                8.2                            -0.6
# 4                                4.7                             2.1
# ...                              ...                             ...
# 8427                             3.0                            -2.7
# 8428                             6.0                            -2.4
# 8429                             2.7                             0.0
# 8430                             2.5                             1.3
# 8431                             2.2                            -0.1
#
#       Rainfall amount (millimetres)
# 0                               6.6
# 1                               3.8
# 2                               0.0
# 3                               0.0
# 4                               0.0
# ...                             ...
# 8427                            4.2
# 8428                            0.2
# 8429                           10.2
# 8430                           15.6
# 8431                           54.4
#
# [8432 rows x 7 columns]

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8432 entries, 0 to 8431
# Data columns (total 7 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Bureau of Meteorology station number  8432 non-null   int64
#  1   Year                                  8432 non-null   int64
#  2   Month                                 8432 non-null   int64
#  3   Day                                   8432 non-null   int64
#  4   Maximum temperature (Degree C)        8116 non-null   float64
#  5   Minimum temperature (Degree C)        8125 non-null   float64
#  6   Rainfall amount (millimetres)         8087 non-null   float64
# dtypes: float64(3), int64(4)
# memory usage: 461.3 KB

# %%
climate_missing_values_count = cd.isnull().sum()
climate_missing_values_count
# Out:
# Bureau of Meteorology station number      0
# Year                                      0
# Month                                     0
# Day                                       0
# Maximum temperature (Degree C)          316
# Minimum temperature (Degree C)          307
# Rainfall amount (millimetres)           345
# dtype: int64

# %% [markdown]
# The climate dataset still has missing values. In fact:
# - Max temperature has 316 missing values
# - Min temperature has 307 missing values
# - Rainfall has 345 missing values

# %%
# how many total missing values do we have?
total_cells = np.prod(cd.shape)
total_missing = climate_missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 1.6400108430468963

# %% [markdown]
# Missing data accounts for 1.64% of the newly edited climate dataset.

# %% [markdown]
# Start of data cleaning process:

# %%
# Forward filled na values for max and minimum temperatures for each ski resort respectively.
# Forward fill was used, as temperatures generally don’t fluctuate drastically from day to day.

cleaned_cd = cd.copy()
cleaned_cd[['Maximum temperature (Degree C)', 'Minimum temperature (Degree C)']] = cleaned_cd[['Maximum temperature (Degree C)', 'Minimum temperature (Degree C)']].fillna(method="ffill")
cleaned_cd
# Out:
# /tmp/ipython-input-1697939588.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   cleaned_cd[['Maximum temperature (Degree C)', 'Minimum temperature (Degree C)']] = cleaned_cd[['Maximum temperature (Degree C)', 'Minimum temperature (Degree C)']].fillna(method="ffill")
#       Bureau of Meteorology station number  Year  Month  Day  \
# 0                                    71075  2014      6    9
# 1                                    71075  2014      6   10
# 2                                    71075  2014      6   11
# 3                                    71075  2014      6   12
# 4                                    71075  2014      6   13
# ...                                    ...   ...    ...  ...
# 8427                                 72161  2025      7   24
# 8428                                 72161  2025      7   25
# 8429                                 72161  2025      7   26
# 8430                                 72161  2025      7   27
# 8431                                 72161  2025      7   28
#
#       Maximum temperature (Degree C)  Minimum temperature (Degree C)  \
# 0                                3.4                            -1.8
# 1                                8.1                            -5.0
# 2                               13.4                            -5.1
# 3                                8.2                            -0.6
# 4                                4.7                             2.1
# ...                              ...                             ...
# 8427                             3.0                            -2.7
# 8428                             6.0                            -2.4
# 8429                             2.7                             0.0
# 8430                             2.5                             1.3
# 8431                             2.2                            -0.1
#
#       Rainfall amount (millimetres)
# 0                               6.6
# 1                               3.8
# 2                               0.0
# 3                               0.0
# 4                               0.0
# ...                             ...
# 8427                            4.2
# 8428                            0.2
# 8429                           10.2
# 8430                           15.6
# 8431                           54.4
#
# [8432 rows x 7 columns]

# %%
# Filled na values in rainfall amount with 0, as there is a good chance that there was no rainfall that day and that the employees
# forgot to record the data.
# However, this is an assumption.

cleaned_cd[['Rainfall amount (millimetres)']] = cleaned_cd[['Rainfall amount (millimetres)']].fillna(0)
cleaned_cd
# Out:
#       Bureau of Meteorology station number  Year  Month  Day  \
# 0                                    71075  2014      6    9
# 1                                    71075  2014      6   10
# 2                                    71075  2014      6   11
# 3                                    71075  2014      6   12
# 4                                    71075  2014      6   13
# ...                                    ...   ...    ...  ...
# 8427                                 72161  2025      7   24
# 8428                                 72161  2025      7   25
# 8429                                 72161  2025      7   26
# 8430                                 72161  2025      7   27
# 8431                                 72161  2025      7   28
#
#       Maximum temperature (Degree C)  Minimum temperature (Degree C)  \
# 0                                3.4                            -1.8
# 1                                8.1                            -5.0
# 2                               13.4                            -5.1
# 3                                8.2                            -0.6
# 4                                4.7                             2.1
# ...                              ...                             ...
# 8427                             3.0                            -2.7
# 8428                             6.0                            -2.4
# 8429                             2.7                             0.0
# 8430                             2.5                             1.3
# 8431                             2.2                            -0.1
#
#       Rainfall amount (millimetres)
# 0                               6.6
# 1                               3.8
# 2                               0.0
# 3                               0.0
# 4                               0.0
# ...                             ...
# 8427                            4.2
# 8428                            0.2
# 8429                           10.2
# 8430                           15.6
# 8431                           54.4
#
# [8432 rows x 7 columns]

# %%
# Checking if there are missing values (none, which is good!)

cleaned_cd_missing_values = cleaned_cd.isnull().sum()
cleaned_cd_missing_values
# Out:
# Bureau of Meteorology station number    0
# Year                                    0
# Month                                   0
# Day                                     0
# Maximum temperature (Degree C)          0
# Minimum temperature (Degree C)          0
# Rainfall amount (millimetres)           0
# dtype: int64

# %%
# Creating a date column

cleaned_cd['Date'] = pd.to_datetime(cd[['Year', 'Month', 'Day']])
cleaned_cd
# Out:
#       Bureau of Meteorology station number  Year  Month  Day  \
# 0                                    71075  2014      6    9
# 1                                    71075  2014      6   10
# 2                                    71075  2014      6   11
# 3                                    71075  2014      6   12
# 4                                    71075  2014      6   13
# ...                                    ...   ...    ...  ...
# 8427                                 72161  2025      7   24
# 8428                                 72161  2025      7   25
# 8429                                 72161  2025      7   26
# 8430                                 72161  2025      7   27
# 8431                                 72161  2025      7   28
#
#       Maximum temperature (Degree C)  Minimum temperature (Degree C)  \
# 0                                3.4                            -1.8
# 1                                8.1                            -5.0
# 2                               13.4                            -5.1
# 3                                8.2                            -0.6
# 4                                4.7                             2.1
# ...                              ...                             ...
# 8427                             3.0                            -2.7
# 8428                             6.0                            -2.4
# 8429                             2.7                             0.0
# 8430                             2.5                             1.3
# 8431                             2.2                            -0.1
#
#       Rainfall amount (millimetres)       Date
# 0                               6.6 2014-06-09
# 1                               3.8 2014-06-10
# 2                               0.0 2014-06-11
# 3                               0.0 2014-06-12
# 4                               0.0 2014-06-13
# ...                             ...        ...
# 8427                            4.2 2025-07-24
# 8428                            0.2 2025-07-25
# 8429                           10.2 2025-07-26
# 8430                           15.6 2025-07-27
# 8431                           54.4 2025-07-28
#
# [8432 rows x 8 columns]

# %%
# Calculating weekly averages for each measurement

main_climate_data = cleaned_cd.copy()


# Step 1: Sort by Station Number and Date
main_climate_data = main_climate_data.sort_values(['Bureau of Meteorology station number', 'Year', 'Date']).reset_index(drop=True)

# Step 2: Assign a weekly group within each Station
main_climate_data['Week'] = main_climate_data.groupby(['Bureau of Meteorology station number', 'Year']).cumcount() // 7 + 1

# Step 3: Group by Station and Week, then average
weekly_summary = main_climate_data.groupby(['Bureau of Meteorology station number', 'Year', 'Week'])[
    ['Maximum temperature (Degree C)', 'Minimum temperature (Degree C)', 'Rainfall amount (millimetres)']
].mean().reset_index()

# Step 4: Optional – rename week label
weekly_summary['Week'] = 'Week ' + weekly_summary['Week'].astype(str)

# %% [markdown]
# This following code is just to export the new modifications (deleting, imputing etc.) into a csv file

# %%
weekly_summary.to_csv('station_weekly_summary.csv', index=False)
from google.colab import files
files.download('station_weekly_summary.csv')

# %% [markdown]
# The following code shows the weekly averages of maximum temperature, minimum temperature and rainfall for each meteorology station respectively.

# %%
weekly_summary
# Out:
#       Bureau of Meteorology station number  Year    Week  \
# 0                                    71032  2014  Week 1
# 1                                    71032  2014  Week 2
# 2                                    71032  2014  Week 3
# 3                                    71032  2014  Week 4
# 4                                    71032  2014  Week 5
# ...                                    ...   ...     ...
# 1205                                 85291  2025  Week 4
# 1206                                 85291  2025  Week 5
# 1207                                 85291  2025  Week 6
# 1208                                 85291  2025  Week 7
# 1209                                 85291  2025  Week 8
#
#       Maximum temperature (Degree C)  Minimum temperature (Degree C)  \
# 0                           4.714286                       -2.000000
# 1                           2.657143                       -1.685714
# 2                          -1.028571                       -4.114286
# 3                          -1.314286                       -4.357143
# 4                          -1.685714                       -5.185714
# ...                              ...                             ...
# 1205                        4.328571                       -0.485714
# 1206                        2.014286                       -1.457143
# 1207                        1.542857                       -2.214286
# 1208                        2.328571                       -1.457143
# 1209                        0.900000                        0.000000
#
#       Rainfall amount (millimetres)
# 0                          5.800000
# 1                          1.142857
# 2                          0.600000
# 3                          0.057143
# 4                          0.428571
# ...                             ...
# 1205                      18.800000
# 1206                       9.028571
# 1207                       2.828571
# 1208                       4.771429
# 1209                      15.600000
#
# [1210 rows x 6 columns]

# %% [markdown]
# In this next step, I went back to Excel to format the tables and combined them into 1 csv file. This involved matching the Bureau of Meteorology station number with ski resorts. Some assumptions have been made due to incomplete data for some ski resorts:
#
# - The following ski resorts (Thredbo, Perisher, Mt. Buller, Falls Creek, Mt.Hotham and Mt. Baw Baw) each have their respective meteorology station to connect. Thus, these are fine.
#
# - Mt. Stirling is close to Mt. Buller, so the measurements for Mt. Stirling are the same as Mt. Buller
#
# - Selwyn ski resort is close to Cabramurra, so the Cabramurra measurements are used for Selwyn
#
# - Charlotte Pass is nearly equidistant from Thredbo and Perisher. The measurements for Charlotte Pass were calculated as an average between Thredbo and Perisher. This can be seen in the excel formulas in the final csv file.
#
# The final csv file is "Full Visits Climate Data.csv".
# This dataset includes the average measurements for each resort, except for number of visits (which remains unchanged).

# %%
dt = pd.read_csv("Full Visits Climate Data.csv")
dt
# Out:
#     Year/Week  Year  Week  Mt. Baw Baw Visits  \
# 0      2014/1  2014     1                 555
# 1      2014/2  2014     2                 804
# 2      2014/3  2014     3                 993
# 3      2014/4  2014     4                2976
# 4      2014/5  2014     5               11112
# ..        ...   ...   ...                 ...
# 160   2024/11  2024    11                5977
# 161   2024/12  2024    12                3597
# 162   2024/13  2024    13                1500
# 163   2024/14  2024    14                   0
# 164   2024/15  2024    15                   0
#
#      Mt. Baw Baw Maximum temperature (Degree C)  \
# 0                                      4.957143
# 1                                      5.485714
# 2                                      1.042857
# 3                                      2.528571
# 4                                      0.685714
# ..                                          ...
# 160                                    6.157143
# 161                                    5.428571
# 162                                    7.142857
# 163                                    5.628571
# 164                                    2.085714
#
#      Mt. Baw Baw Minimum temperature (Degree C)  \
# 0                                      1.100000
# 1                                      0.814286
# 2                                     -1.814286
# 3                                     -0.957143
# 4                                     -2.257143
# ..                                          ...
# 160                                    1.385714
# 161                                    0.928571
# 162                                   -0.100000
# 163                                    0.528571
# 164                                   -2.028571
#
#      Mt. Baw Baw Rainfall amount (millimetres)  Mt. Stirling Visits  \
# 0                                     3.485714                   60
# 1                                     3.000000                   42
# 2                                    10.914286                   30
# 3                                    11.714286                  165
# 4                                    11.800000                  645
# ..                                         ...                  ...
# 160                                   3.742857                 1416
# 161                                   3.371429                  701
# 162                                   7.228571                  213
# 163                                   6.542857                    0
# 164                                  13.228571                    0
#
#      Mt. Stirling Maximum temperature (Degree C)  \
# 0                                       4.271429
# 1                                       5.257143
# 2                                       0.385714
# 3                                       0.957143
# 4                                      -0.285714
# ..                                           ...
# 160                                     4.885714
# 161                                     4.257143
# 162                                     6.100000
# 163                                     5.728571
# 164                                     2.071429
#
#      Mt. Stirling Minimum temperature (Degree C)  ...  \
# 0                                      -0.014286  ...
# 1                                      -0.342857  ...
# 2                                      -2.514286  ...
# 3                                      -1.857143  ...
# 4                                      -3.400000  ...
# ..                                           ...  ...
# 160                                     0.828571  ...
# 161                                     0.157143  ...
# 162                                    -0.671429  ...
# 163                                    -0.571429  ...
# 164                                    -3.185714  ...
#
#      Perisher Minimum temperature (Degree C)  \
# 0                                  -1.585714
# 1                                  -1.857143
# 2                                  -2.457143
# 3                                  -2.457143
# 4                                  -3.757143
# ..                                       ...
# 160                                 0.085714
# 161                                 0.671429
# 162                                 0.671429
# 163                                -0.728571
# 164                                -2.957143
#
#      Perisher Rainfall amount (millimetres)  Charlotte Pass Visits  \
# 0                                  8.857143                    408
# 1                                  1.971429                    151
# 2                                 31.514286                    230
# 3                                  7.685714                   1134
# 4                                  5.571429                   3403
# ..                                      ...                    ...
# 160                                4.200000                   2667
# 161                               13.257143                   2392
# 162                                5.857143                   1323
# 163                                0.771429                    454
# 164                                5.085714                    294
#
#      Charlotte Maximum temperature (Degree C)  \
# 0                                    5.521429
# 1                                    3.957143
# 2                                   -0.071429
# 3                                    0.814286
# 4                                   -0.250000
# ..                                        ...
# 160                                  4.900000
# 161                                  3.542857
# 162                                  6.300000
# 163                                  7.414286
# 164                                  2.442857
#
#      Charlotte Minimum temperature (Degree C)  \
# 0                                   -1.792857
# 1                                   -1.771429
# 2                                   -3.285714
# 3                                   -3.407143
# 4                                   -4.471429
# ..                                        ...
# 160                                 -0.307143
# 161                                 -0.250000
# 162                                 -0.014286
# 163                                 -0.985714
# 164                                 -3.607143
#
#      Charlotte Rainfall amount (millimetres)  Average Pass Visits  \
# 0                                   7.328571          3282.000000
# 1                                   1.557143          1209.555556
# 2                                  16.057143          1869.666667
# 3                                   3.871429          8996.555556
# 4                                   3.000000         26298.777780
# ..                                       ...                  ...
# 160                                 4.228571         23316.777780
# 161                                11.585714         20811.888890
# 162                                 4.614286         11507.666670
# 163                                 1.200000          3998.000000
# 164                                 3.685714          2603.111111
#
#      Average Maximum temperature (Degree C)  \
# 0                                  4.994444
# 1                                  4.666667
# 2                                  0.274603
# 3                                  1.158730
# 4                                 -0.215079
# ..                                      ...
# 160                                5.169841
# 161                                4.211111
# 162                                6.411111
# 163                                6.509524
# 164                                2.650794
#
#      Average Minimum temperature (Degree C)  \
# 0                                 -0.464286
# 1                                 -0.577778
# 2                                 -2.630159
# 3                                 -2.423016
# 4                                 -3.609524
# ..                                      ...
# 160                                0.559524
# 161                                0.183333
# 162                               -0.141270
# 163                               -0.334921
# 164                               -3.089683
#
#      Average Rainfall amount (millimetres)
# 0                                 4.788889
# 1                                 2.919048
# 2                                13.971429
# 3                                 6.480952
# 4                                 5.546032
# ..                                     ...
# 160                               4.946032
# 161                               8.877778
# 162                               5.252381
# 163                               3.171429
# 164                               5.196825
#
# [165 rows x 43 columns]

# %% [markdown]
# From the plot above, we can see that there is some seasonality.
